# %%
import matplotlib.pyplot as plt

## exp moving average
def EMA(x, y):
    k = 30 / len(x)
    ema_seq = []
    ema_prev = 0
    for t in range(0, len(x)):
        y_t = y[t] * k + ema_prev * (1 - k)
        ema_prev = y_t
        ema_seq.append(y_t)
    return (x, ema_seq)

idx = 20
def new_figure():
    global idx
    idx +=1
    return plt.figure(idx)

line_style=(0, (5, 5))
loc='lower left' 
bbox_to_anchor=(0.9, 0.1)
borderpad=1

# %% [markdown]
# ### Load data with respect to gamma

# %%
## beta = 0.00005
from data_eps_04_gamma_040 import *
(eps_04_g_040_s_x_ema, eps_04_g_040_s_r_ema) = EMA(eps_04_gamma_040_SARSA_x_training_seq, eps_04_gamma_040_SARSA_R_training_seq)
(eps_04_g_040_q_x_ema, eps_04_g_040_q_r_ema) = EMA(eps_04_gamma_040_Q_Learning_x_training_seq, eps_04_gamma_040_Q_Learning_R_training_seq)
(_, eps_04_g_040_s_n_ema) = EMA(eps_04_gamma_040_SARSA_x_training_seq, eps_04_gamma_040_SARSA_N_training_seq)
(_, eps_04_g_040_q_n_ema) = EMA(eps_04_gamma_040_Q_Learning_x_training_seq, eps_04_gamma_040_Q_Learning_N_training_seq)

from data_eps_04_gamma_055 import *
(eps_04_g_055_s_x_ema, eps_04_g_055_s_r_ema) = EMA(eps_04_gamma_055_SARSA_x_training_seq, eps_04_gamma_055_SARSA_R_training_seq)
(eps_04_g_055_q_x_ema, eps_04_g_055_q_r_ema) = EMA(eps_04_gamma_055_Q_Learning_x_training_seq, eps_04_gamma_055_Q_Learning_R_training_seq)
(_, eps_04_g_055_s_n_ema) = EMA(eps_04_gamma_055_SARSA_x_training_seq, eps_04_gamma_055_SARSA_N_training_seq)
(_, eps_04_g_055_q_n_ema) = EMA(eps_04_gamma_055_Q_Learning_x_training_seq, eps_04_gamma_055_Q_Learning_N_training_seq)

from data_eps_04_gamma_07 import *
(eps_04_g_07_s_x_ema, eps_04_g_07_s_r_ema) = EMA(eps_04_gamma_07_SARSA_x_training_seq, eps_04_gamma_07_SARSA_R_training_seq)
(eps_04_g_07_q_x_ema, eps_04_g_07_q_r_ema) = EMA(eps_04_gamma_07_Q_Learning_x_training_seq, eps_04_gamma_07_Q_Learning_R_training_seq)
(_, eps_04_g_07_s_n_ema) = EMA(eps_04_gamma_07_SARSA_x_training_seq, eps_04_gamma_07_SARSA_N_training_seq)
(_, eps_04_g_07_q_n_ema) = EMA(eps_04_gamma_07_Q_Learning_x_training_seq, eps_04_gamma_07_Q_Learning_N_training_seq)

from data_eps_04_gamma_85 import *
(eps_04_g_85_s_x_ema, eps_04_g_85_s_r_ema) = EMA(eps_04_gamma_85_SARSA_x_training_seq, eps_04_gamma_85_SARSA_R_training_seq)
(eps_04_g_85_q_x_ema, eps_04_g_85_q_r_ema) = EMA(eps_04_gamma_85_Q_Learning_x_training_seq, eps_04_gamma_85_Q_Learning_R_training_seq)
(_, eps_04_g_85_s_n_ema) = EMA(eps_04_gamma_85_SARSA_x_training_seq, eps_04_gamma_85_SARSA_N_training_seq)
(_, eps_04_g_85_q_n_ema) = EMA(eps_04_gamma_85_Q_Learning_x_training_seq, eps_04_gamma_85_Q_Learning_N_training_seq)

from data_eps_04_gamma_99 import *
(eps_04_g_99_s_x_ema, eps_04_g_99_s_r_ema) = EMA(eps_04_gamma_99_SARSA_x_training_seq, eps_04_gamma_99_SARSA_R_training_seq)
(eps_04_g_99_q_x_ema, eps_04_g_99_q_r_ema) = EMA(eps_04_gamma_99_Q_Learning_x_training_seq, eps_04_gamma_99_Q_Learning_R_training_seq)
(_, eps_04_g_99_s_n_ema) = EMA(eps_04_gamma_99_SARSA_x_training_seq, eps_04_gamma_99_SARSA_N_training_seq)
(_, eps_04_g_99_q_n_ema) = EMA(eps_04_gamma_99_Q_Learning_x_training_seq, eps_04_gamma_99_Q_Learning_N_training_seq)

from data_eps_04_gamma_001 import *
(eps_04_g_001_s_x_ema, eps_04_g_001_s_r_ema) = EMA(eps_04_gamma_001_beta_SARSA_x_training_seq, eps_04_gamma_001_beta_SARSA_R_training_seq)
(eps_04_g_001_q_x_ema, eps_04_g_001_q_r_ema) = EMA(eps_04_gamma_001_beta_Q_Learning_x_training_seq, eps_04_gamma_001_beta_Q_Learning_R_training_seq)
(_, eps_04_g_001_s_n_ema) = EMA(eps_04_gamma_001_beta_SARSA_x_training_seq, eps_04_gamma_001_beta_SARSA_N_training_seq)
(_, eps_04_g_001_q_n_ema) = EMA(eps_04_gamma_001_beta_Q_Learning_x_training_seq, eps_04_gamma_001_beta_Q_Learning_N_training_seq)

from data_eps_04_gamma_02 import *
(eps_04_g_02_s_x_ema, eps_04_g_02_s_r_ema) = EMA(eps_04_gamma_02_SARSA_x_training_seq, eps_04_gamma_02_SARSA_R_training_seq)
(eps_04_g_02_q_x_ema, eps_04_g_02_q_r_ema) = EMA(eps_04_gamma_02_Q_Learning_x_training_seq, eps_04_gamma_02_Q_Learning_R_training_seq)
(_, eps_04_g_02_s_n_ema) = EMA(eps_04_gamma_02_SARSA_x_training_seq, eps_04_gamma_02_SARSA_N_training_seq)
(_, eps_04_g_02_q_n_ema) = EMA(eps_04_gamma_02_Q_Learning_x_training_seq, eps_04_gamma_02_Q_Learning_N_training_seq)

# %% [markdown]
# ### Load data with respect to beta

# %%
from data_gamma_07_eps_04_beta_00100 import *
(b_00100_g_07_s_x_ema, b_00100_g_07_s_r_ema) = EMA(gamma_07_eps_04_beta_00100_SARSA_x_training_seq, gamma_07_eps_04_beta_00100_SARSA_R_training_seq)
(b_00100_g_07_q_x_ema, b_00100_g_07_q_r_ema) = EMA(gamma_07_eps_04_beta_00100_Q_Learning_x_training_seq, gamma_07_eps_04_beta_00100_Q_Learning_R_training_seq)
(_, b_00100_g_07_s_n_ema) = EMA(gamma_07_eps_04_beta_00100_SARSA_x_training_seq, gamma_07_eps_04_beta_00100_SARSA_N_training_seq)
(_, b_00100_g_07_q_n_ema) = EMA(gamma_07_eps_04_beta_00100_Q_Learning_x_training_seq, gamma_07_eps_04_beta_00100_Q_Learning_N_training_seq)

(b_00100_g_07_s_x_val, b_00100_g_07_s_r_val) = (gamma_07_eps_04_beta_00100_SARSA_x_axis, gamma_07_eps_04_beta_00100_SARSA_avg_R)
(b_00100_g_07_q_x_val, b_00100_g_07_q_r_val) = (gamma_07_eps_04_beta_00100_Q_Learning_x_axis, gamma_07_eps_04_beta_00100_Q_Learning_avg_R)
(_, b_00100_g_07_s_n_val) = (gamma_07_eps_04_beta_00100_SARSA_x_axis, gamma_07_eps_04_beta_00100_SARSA_avg_N)
(_, b_00100_g_07_q_n_val) = (gamma_07_eps_04_beta_00100_Q_Learning_x_axis, gamma_07_eps_04_beta_00100_Q_Learning_avg_N)

from data_gamma_07_eps_04_beta_00200 import *
(b_00200_g_07_s_x_ema, b_00200_g_07_s_r_ema) = EMA(gamma_07_eps_04_beta_00200_SARSA_x_training_seq, gamma_07_eps_04_beta_00200_SARSA_R_training_seq)
(b_00200_g_07_q_x_ema, b_00200_g_07_q_r_ema) = EMA(gamma_07_eps_04_beta_00200_Q_Learning_x_training_seq, gamma_07_eps_04_beta_00200_Q_Learning_R_training_seq)
(_, b_00200_g_07_s_n_ema) = EMA(gamma_07_eps_04_beta_00200_SARSA_x_training_seq, gamma_07_eps_04_beta_00200_SARSA_N_training_seq)
(_, b_00200_g_07_q_n_ema) = EMA(gamma_07_eps_04_beta_00200_Q_Learning_x_training_seq, gamma_07_eps_04_beta_00200_Q_Learning_N_training_seq)

(b_00200_g_07_s_x_val, b_00200_g_07_s_r_val) = (gamma_07_eps_04_beta_00200_SARSA_x_axis, gamma_07_eps_04_beta_00200_SARSA_avg_R)
(b_00200_g_07_q_x_val, b_00200_g_07_q_r_val) = (gamma_07_eps_04_beta_00200_Q_Learning_x_axis, gamma_07_eps_04_beta_00200_Q_Learning_avg_R)
(_, b_00200_g_07_s_n_val) = (gamma_07_eps_04_beta_00200_SARSA_x_axis, gamma_07_eps_04_beta_00200_SARSA_avg_N)
(_, b_00200_g_07_q_n_val) = (gamma_07_eps_04_beta_00200_Q_Learning_x_axis, gamma_07_eps_04_beta_00200_Q_Learning_avg_N)

from data_gamma_07_eps_04_beta_00300 import *
(b_00300_g_07_s_x_ema, b_00300_g_07_s_r_ema) = EMA(gamma_07_eps_04_beta_00300_SARSA_x_training_seq, gamma_07_eps_04_beta_00300_SARSA_R_training_seq)
(b_00300_g_07_q_x_ema, b_00300_g_07_q_r_ema) = EMA(gamma_07_eps_04_beta_00300_Q_Learning_x_training_seq, gamma_07_eps_04_beta_00300_Q_Learning_R_training_seq)
(_, b_00300_g_07_s_n_ema) = EMA(gamma_07_eps_04_beta_00300_SARSA_x_training_seq, gamma_07_eps_04_beta_00300_SARSA_N_training_seq)
(_, b_00300_g_07_q_n_ema) = EMA(gamma_07_eps_04_beta_00300_Q_Learning_x_training_seq, gamma_07_eps_04_beta_00300_Q_Learning_N_training_seq)

(b_00300_g_07_s_x_val, b_00300_g_07_s_r_val) = (gamma_07_eps_04_beta_00300_SARSA_x_axis, gamma_07_eps_04_beta_00300_SARSA_avg_R)
(b_00300_g_07_q_x_val, b_00300_g_07_q_r_val) = (gamma_07_eps_04_beta_00300_Q_Learning_x_axis, gamma_07_eps_04_beta_00300_Q_Learning_avg_R)
(_, b_00300_g_07_s_n_val) = (gamma_07_eps_04_beta_00300_SARSA_x_axis, gamma_07_eps_04_beta_00300_SARSA_avg_N)
(_, b_00300_g_07_q_n_val) = (gamma_07_eps_04_beta_00300_Q_Learning_x_axis, gamma_07_eps_04_beta_00300_Q_Learning_avg_N)

from data_gamma_07_eps_04_beta_00500 import *
(b_00500_g_07_s_x_ema, b_00500_g_07_s_r_ema) = EMA(gamma_07_eps_04_beta_00500_SARSA_x_training_seq, gamma_07_eps_04_beta_00500_SARSA_R_training_seq)
(b_00500_g_07_q_x_ema, b_00500_g_07_q_r_ema) = EMA(gamma_07_eps_04_beta_00500_Q_Learning_x_training_seq, gamma_07_eps_04_beta_00500_Q_Learning_R_training_seq)
(_, b_00500_g_07_s_n_ema) = EMA(gamma_07_eps_04_beta_00500_SARSA_x_training_seq, gamma_07_eps_04_beta_00500_SARSA_N_training_seq)
(_, b_00500_g_07_q_n_ema) = EMA(gamma_07_eps_04_beta_00500_Q_Learning_x_training_seq, gamma_07_eps_04_beta_00500_Q_Learning_N_training_seq)

(b_00500_g_07_s_x_val, b_00500_g_07_s_r_val) = (gamma_07_eps_04_beta_00500_SARSA_x_axis, gamma_07_eps_04_beta_00500_SARSA_avg_R)
(b_00500_g_07_q_x_val, b_00500_g_07_q_r_val) = (gamma_07_eps_04_beta_00500_Q_Learning_x_axis, gamma_07_eps_04_beta_00500_Q_Learning_avg_R)
(_, b_00500_g_07_s_n_val) = (gamma_07_eps_04_beta_00500_SARSA_x_axis, gamma_07_eps_04_beta_00500_SARSA_avg_N)
(_, b_00500_g_07_q_n_val) = (gamma_07_eps_04_beta_00500_Q_Learning_x_axis, gamma_07_eps_04_beta_00500_Q_Learning_avg_N)

from data_gamma_07_eps_04_beta_00700 import *
(b_00700_g_07_s_x_ema, b_00700_g_07_s_r_ema) = EMA(gamma_07_eps_04_beta_00700_SARSA_x_training_seq, gamma_07_eps_04_beta_00700_SARSA_R_training_seq)
(b_00700_g_07_q_x_ema, b_00700_g_07_q_r_ema) = EMA(gamma_07_eps_04_beta_00700_Q_Learning_x_training_seq, gamma_07_eps_04_beta_00700_Q_Learning_R_training_seq)
(_, b_00700_g_07_s_n_ema) = EMA(gamma_07_eps_04_beta_00700_SARSA_x_training_seq, gamma_07_eps_04_beta_00700_SARSA_N_training_seq)
(_, b_00700_g_07_q_n_ema) = EMA(gamma_07_eps_04_beta_00700_Q_Learning_x_training_seq, gamma_07_eps_04_beta_00700_Q_Learning_N_training_seq)

(b_00700_g_07_s_x_val, b_00700_g_07_s_r_val) = (gamma_07_eps_04_beta_00700_SARSA_x_axis, gamma_07_eps_04_beta_00700_SARSA_avg_R)
(b_00700_g_07_q_x_val, b_00700_g_07_q_r_val) = (gamma_07_eps_04_beta_00700_Q_Learning_x_axis, gamma_07_eps_04_beta_00700_Q_Learning_avg_R)
(_, b_00700_g_07_s_n_val) = (gamma_07_eps_04_beta_00700_SARSA_x_axis, gamma_07_eps_04_beta_00700_SARSA_avg_N)
(_, b_00700_g_07_q_n_val) = (gamma_07_eps_04_beta_00700_Q_Learning_x_axis, gamma_07_eps_04_beta_00700_Q_Learning_avg_N)

from data_gamma_07_eps_04_beta_00900 import *
(b_00900_g_07_s_x_ema, b_00900_g_07_s_r_ema) = EMA(gamma_07_eps_04_beta_00900_SARSA_x_training_seq, gamma_07_eps_04_beta_00900_SARSA_R_training_seq)
(b_00900_g_07_q_x_ema, b_00900_g_07_q_r_ema) = EMA(gamma_07_eps_04_beta_00900_Q_Learning_x_training_seq, gamma_07_eps_04_beta_00900_Q_Learning_R_training_seq)
(_, b_00900_g_07_s_n_ema) = EMA(gamma_07_eps_04_beta_00900_SARSA_x_training_seq, gamma_07_eps_04_beta_00900_SARSA_N_training_seq)
(_, b_00900_g_07_q_n_ema) = EMA(gamma_07_eps_04_beta_00900_Q_Learning_x_training_seq, gamma_07_eps_04_beta_00900_Q_Learning_N_training_seq)

(b_00900_g_07_s_x_val, b_00900_g_07_s_r_val) = (gamma_07_eps_04_beta_00900_SARSA_x_axis, gamma_07_eps_04_beta_00900_SARSA_avg_R)
(b_00900_g_07_q_x_val, b_00900_g_07_q_r_val) = (gamma_07_eps_04_beta_00900_Q_Learning_x_axis, gamma_07_eps_04_beta_00900_Q_Learning_avg_R)
(_, b_00900_g_07_s_n_val) = (gamma_07_eps_04_beta_00900_SARSA_x_axis, gamma_07_eps_04_beta_00900_SARSA_avg_N)
(_, b_00900_g_07_q_n_val) = (gamma_07_eps_04_beta_00900_Q_Learning_x_axis, gamma_07_eps_04_beta_00900_Q_Learning_avg_N)

from data_gamma_07_eps_04_beta_01000 import *
(b_01000_g_07_s_x_ema, b_01000_g_07_s_r_ema) = EMA(gamma_07_eps_04_beta_01000_SARSA_x_training_seq, gamma_07_eps_04_beta_01000_SARSA_R_training_seq)
(b_01000_g_07_q_x_ema, b_01000_g_07_q_r_ema) = EMA(gamma_07_eps_04_beta_01000_Q_Learning_x_training_seq, gamma_07_eps_04_beta_01000_Q_Learning_R_training_seq)
(_, b_01000_g_07_s_n_ema) = EMA(gamma_07_eps_04_beta_01000_SARSA_x_training_seq, gamma_07_eps_04_beta_01000_SARSA_N_training_seq)
(_, b_01000_g_07_q_n_ema) = EMA(gamma_07_eps_04_beta_01000_Q_Learning_x_training_seq, gamma_07_eps_04_beta_01000_Q_Learning_N_training_seq)

(b_01000_g_07_s_x_val, b_01000_g_07_s_r_val) = (gamma_07_eps_04_beta_01000_SARSA_x_axis, gamma_07_eps_04_beta_01000_SARSA_avg_R)
(b_01000_g_07_q_x_val, b_01000_g_07_q_r_val) = (gamma_07_eps_04_beta_01000_Q_Learning_x_axis, gamma_07_eps_04_beta_01000_Q_Learning_avg_R)
(_, b_01000_g_07_s_n_val) = (gamma_07_eps_04_beta_01000_SARSA_x_axis, gamma_07_eps_04_beta_01000_SARSA_avg_N)
(_, b_01000_g_07_q_n_val) = (gamma_07_eps_04_beta_01000_Q_Learning_x_axis, gamma_07_eps_04_beta_01000_Q_Learning_avg_N)

from data_gamma_07_eps_04_beta_02000 import *
(b_02000_g_07_s_x_ema, b_02000_g_07_s_r_ema) = EMA(gamma_07_eps_04_beta_02000_SARSA_x_training_seq, gamma_07_eps_04_beta_02000_SARSA_R_training_seq)
(b_02000_g_07_q_x_ema, b_02000_g_07_q_r_ema) = EMA(gamma_07_eps_04_beta_02000_Q_Learning_x_training_seq, gamma_07_eps_04_beta_02000_Q_Learning_R_training_seq)
(_, b_02000_g_07_s_n_ema) = EMA(gamma_07_eps_04_beta_02000_SARSA_x_training_seq, gamma_07_eps_04_beta_02000_SARSA_N_training_seq)
(_, b_02000_g_07_q_n_ema) = EMA(gamma_07_eps_04_beta_02000_Q_Learning_x_training_seq, gamma_07_eps_04_beta_02000_Q_Learning_N_training_seq)

(b_02000_g_07_s_x_val, b_02000_g_07_s_r_val) = (gamma_07_eps_04_beta_02000_SARSA_x_axis, gamma_07_eps_04_beta_02000_SARSA_avg_R)
(b_02000_g_07_q_x_val, b_02000_g_07_q_r_val) = (gamma_07_eps_04_beta_02000_Q_Learning_x_axis, gamma_07_eps_04_beta_02000_Q_Learning_avg_R)
(_, b_02000_g_07_s_n_val) = (gamma_07_eps_04_beta_02000_SARSA_x_axis, gamma_07_eps_04_beta_02000_SARSA_avg_N)
(_, b_02000_g_07_q_n_val) = (gamma_07_eps_04_beta_02000_Q_Learning_x_axis, gamma_07_eps_04_beta_02000_Q_Learning_avg_N)
from data_gamma_07_eps_04_beta_04000 import *
(b_04000_g_07_s_x_ema, b_04000_g_07_s_r_ema) = EMA(gamma_07_eps_04_beta_04000_SARSA_x_training_seq, gamma_07_eps_04_beta_04000_SARSA_R_training_seq)
(b_04000_g_07_q_x_ema, b_04000_g_07_q_r_ema) = EMA(gamma_07_eps_04_beta_04000_Q_Learning_x_training_seq, gamma_07_eps_04_beta_04000_Q_Learning_R_training_seq)
(_, b_04000_g_07_s_n_ema) = EMA(gamma_07_eps_04_beta_04000_SARSA_x_training_seq, gamma_07_eps_04_beta_04000_SARSA_N_training_seq)
(_, b_04000_g_07_q_n_ema) = EMA(gamma_07_eps_04_beta_04000_Q_Learning_x_training_seq, gamma_07_eps_04_beta_04000_Q_Learning_N_training_seq)

(b_04000_g_07_s_x_val, b_04000_g_07_s_r_val) = (gamma_07_eps_04_beta_04000_SARSA_x_axis, gamma_07_eps_04_beta_04000_SARSA_avg_R)
(b_04000_g_07_q_x_val, b_04000_g_07_q_r_val) = (gamma_07_eps_04_beta_04000_Q_Learning_x_axis, gamma_07_eps_04_beta_04000_Q_Learning_avg_R)
(_, b_04000_g_07_s_n_val) = (gamma_07_eps_04_beta_04000_SARSA_x_axis, gamma_07_eps_04_beta_04000_SARSA_avg_N)
(_, b_04000_g_07_q_n_val) = (gamma_07_eps_04_beta_04000_Q_Learning_x_axis, gamma_07_eps_04_beta_04000_Q_Learning_avg_N)

from data_gamma_07_eps_04_beta_10000 import *
(b_10000_g_07_s_x_ema, b_10000_g_07_s_r_ema) = EMA(gamma_07_eps_04_beta_10000_SARSA_x_training_seq, gamma_07_eps_04_beta_10000_SARSA_R_training_seq)
(b_10000_g_07_q_x_ema, b_10000_g_07_q_r_ema) = EMA(gamma_07_eps_04_beta_10000_Q_Learning_x_training_seq, gamma_07_eps_04_beta_10000_Q_Learning_R_training_seq)
(_, b_10000_g_07_s_n_ema) = EMA(gamma_07_eps_04_beta_10000_SARSA_x_training_seq, gamma_07_eps_04_beta_10000_SARSA_N_training_seq)
(_, b_10000_g_07_q_n_ema) = EMA(gamma_07_eps_04_beta_10000_Q_Learning_x_training_seq, gamma_07_eps_04_beta_10000_Q_Learning_N_training_seq)

(b_10000_g_07_s_x_val, b_10000_g_07_s_r_val) = (gamma_07_eps_04_beta_10000_SARSA_x_axis, gamma_07_eps_04_beta_10000_SARSA_avg_R)
(b_10000_g_07_q_x_val, b_10000_g_07_q_r_val) = (gamma_07_eps_04_beta_10000_Q_Learning_x_axis, gamma_07_eps_04_beta_10000_Q_Learning_avg_R)
(_, b_10000_g_07_s_n_val) = (gamma_07_eps_04_beta_10000_SARSA_x_axis, gamma_07_eps_04_beta_10000_SARSA_avg_N)
(_, b_10000_g_07_q_n_val) = (gamma_07_eps_04_beta_10000_Q_Learning_x_axis, gamma_07_eps_04_beta_10000_Q_Learning_avg_N)

from data_gamma_07_eps_04_beta_30000 import *
(b_30000_g_07_s_x_ema, b_30000_g_07_s_r_ema) = EMA(gamma_07_eps_04_beta_30000_SARSA_x_training_seq, gamma_07_eps_04_beta_30000_SARSA_R_training_seq)
(b_30000_g_07_q_x_ema, b_30000_g_07_q_r_ema) = EMA(gamma_07_eps_04_beta_30000_Q_Learning_x_training_seq, gamma_07_eps_04_beta_30000_Q_Learning_R_training_seq)
(_, b_30000_g_07_s_n_ema) = EMA(gamma_07_eps_04_beta_30000_SARSA_x_training_seq, gamma_07_eps_04_beta_30000_SARSA_N_training_seq)
(_, b_30000_g_07_q_n_ema) = EMA(gamma_07_eps_04_beta_30000_Q_Learning_x_training_seq, gamma_07_eps_04_beta_30000_Q_Learning_N_training_seq)

(b_30000_g_07_s_x_val, b_30000_g_07_s_r_val) = (gamma_07_eps_04_beta_30000_SARSA_x_axis, gamma_07_eps_04_beta_30000_SARSA_avg_R)
(b_30000_g_07_q_x_val, b_30000_g_07_q_r_val) = (gamma_07_eps_04_beta_30000_Q_Learning_x_axis, gamma_07_eps_04_beta_30000_Q_Learning_avg_R)
(_, b_30000_g_07_s_n_val) = (gamma_07_eps_04_beta_30000_SARSA_x_axis, gamma_07_eps_04_beta_30000_SARSA_avg_N)
(_, b_30000_g_07_q_n_val) = (gamma_07_eps_04_beta_30000_Q_Learning_x_axis, gamma_07_eps_04_beta_30000_Q_Learning_avg_N)

from data_gamma_07_eps_04_beta_20000 import *
(b_20000_g_07_s_x_ema, b_20000_g_07_s_r_ema) = EMA(gamma_07_eps_04_beta_20000_SARSA_x_training_seq, gamma_07_eps_04_beta_20000_SARSA_R_training_seq)
(b_20000_g_07_q_x_ema, b_20000_g_07_q_r_ema) = EMA(gamma_07_eps_04_beta_20000_Q_Learning_x_training_seq, gamma_07_eps_04_beta_20000_Q_Learning_R_training_seq)
(_, b_20000_g_07_s_n_ema) = EMA(gamma_07_eps_04_beta_20000_SARSA_x_training_seq, gamma_07_eps_04_beta_20000_SARSA_N_training_seq)
(_, b_20000_g_07_q_n_ema) = EMA(gamma_07_eps_04_beta_20000_Q_Learning_x_training_seq, gamma_07_eps_04_beta_20000_Q_Learning_N_training_seq)

(b_20000_g_07_s_x_val, b_20000_g_07_s_r_val) = (gamma_07_eps_04_beta_20000_SARSA_x_axis, gamma_07_eps_04_beta_20000_SARSA_avg_R)
(b_20000_g_07_q_x_val, b_20000_g_07_q_r_val) = (gamma_07_eps_04_beta_20000_Q_Learning_x_axis, gamma_07_eps_04_beta_20000_Q_Learning_avg_R)
(_, b_20000_g_07_s_n_val) = (gamma_07_eps_04_beta_20000_SARSA_x_axis, gamma_07_eps_04_beta_20000_SARSA_avg_N)
(_, b_20000_g_07_q_n_val) = (gamma_07_eps_04_beta_20000_Q_Learning_x_axis, gamma_07_eps_04_beta_20000_Q_Learning_avg_N)

# %% [markdown]
# ## Training curves vs gamma

# %% [markdown]
# ### SARSA Training curves vs gamma

# %%
new_figure()

fig, ax  = plt.subplots()
plt.title("SARSA - N vs γ")
ax.set_xlabel("episodes")
ax.set_ylabel("N")

ax.plot(eps_04_g_001_s_x_ema, eps_04_g_001_s_n_ema, label="γ=0.001")
ax.plot(eps_04_g_02_s_x_ema, eps_04_g_02_s_n_ema, label="γ=0.2")
ax.plot(eps_04_g_040_s_x_ema, eps_04_g_040_s_n_ema, label="γ=0.4")
ax.plot(eps_04_g_055_s_x_ema, eps_04_g_055_s_n_ema, label="γ=0.55")
ax.plot(eps_04_g_07_s_x_ema, eps_04_g_07_s_n_ema, label="γ=0.7")
ax.plot(eps_04_g_85_s_x_ema, eps_04_g_85_s_n_ema, label="γ=0.85")
ax.plot(eps_04_g_99_s_x_ema, eps_04_g_99_s_n_ema, label="γ=0.99")
# ax.set_ylim((1.5, 6.1))
# ax.set_xlim((0,25000))
ax.grid('on')

# ax2 = ax
# ax2.set_ylabel("R (- -)")
# ax2.plot(eps_04_g_001_s_x_ema, eps_04_g_001_s_r_ema, label="γ=0.001", linestyle=line_style)
# ax2.plot(eps_04_g_02_s_x_ema, eps_04_g_02_s_r_ema, label="γ=0.2", linestyle=line_style)
# ax2.plot(eps_04_g_040_s_x_ema, eps_04_g_040_s_r_ema, label="γ=0.4", linestyle=line_style)
# ax2.plot(eps_04_g_055_s_x_ema, eps_04_g_055_s_r_ema, label="γ=0.55", linestyle=line_style)
# ax2.plot(eps_04_g_07_s_x_ema, eps_04_g_07_s_r_ema, label="γ=0.7", linestyle=line_style)
# ax2.plot(eps_04_g_85_s_x_ema, eps_04_g_85_s_r_ema, label="γ=0.85", linestyle=line_style)
# ax2.plot(eps_04_g_99_s_x_ema, eps_04_g_99_s_r_ema, label="γ=0.99", linestyle=line_style)
ax.plot()
bbox_to_anchor=(0.85,0.1)
lgd = fig.legend(loc=loc, bbox_to_anchor=bbox_to_anchor, borderpad=1)
text = fig.text(-0.2,1.05, "", transform=ax.transAxes) 
plt.show()
fig.savefig("../plot/SARSA-γ_n_peak.jpg",bbox_extra_artists=(lgd,text), bbox_inches='tight', dpi=100)

##########################################
new_figure()
fig2, ax2  = plt.subplots()
plt.title("SARSA - R vs γ")
ax2.set_xlabel("episodes")
ax2.set_ylabel("R")

ax2.grid('on')
ax2.set_ylabel("R")
ax2.plot(eps_04_g_001_s_x_ema, eps_04_g_001_s_r_ema, label="γ=0.001")
ax2.plot(eps_04_g_02_s_x_ema, eps_04_g_02_s_r_ema, label="γ=0.2")
ax2.plot(eps_04_g_040_s_x_ema, eps_04_g_040_s_r_ema, label="γ=0.4")
ax2.plot(eps_04_g_055_s_x_ema, eps_04_g_055_s_r_ema, label="γ=0.55")
ax2.plot(eps_04_g_07_s_x_ema, eps_04_g_07_s_r_ema, label="γ=0.7")
ax2.plot(eps_04_g_85_s_x_ema, eps_04_g_85_s_r_ema, label="γ=0.85")
ax2.plot(eps_04_g_99_s_x_ema, eps_04_g_99_s_r_ema, label="γ=0.99")
ax2.plot()

# ax2.set_ylim((0.4, 1.02))
# ax2.set_xlim((0,50000))
bbox_to_anchor = (0.9,0.1)
lgd = fig2.legend(loc=loc, bbox_to_anchor=bbox_to_anchor, borderpad=1)
text = fig2.text(-0.2,1.05, "", transform=ax.transAxes) 
plt.show()
fig2.savefig("../plot/SARSA-γ_r_peak.jpg",bbox_extra_artists=(lgd,text), bbox_inches='tight', dpi=100)

# %% [markdown]
# ### Q Training vs gamma

# %%
new_figure()


fig, ax  = plt.subplots()
plt.title("Q Learning - N vs γ")
ax.set_xlabel("episodes")
ax.set_ylabel("N")

ax.plot(eps_04_g_001_q_x_ema, eps_04_g_001_q_n_ema, label="γ=0.001")
ax.plot(eps_04_g_02_q_x_ema, eps_04_g_02_q_n_ema, label="γ=0.2")
ax.plot(eps_04_g_040_q_x_ema, eps_04_g_040_q_n_ema, label="γ=0.4")
ax.plot(eps_04_g_055_q_x_ema, eps_04_g_055_q_n_ema, label="γ=0.55")
ax.plot(eps_04_g_07_q_x_ema, eps_04_g_07_q_n_ema, label="γ=0.7")
ax.plot(eps_04_g_85_q_x_ema, eps_04_g_85_q_n_ema, label="γ=0.85")
ax.plot(eps_04_g_99_q_x_ema, eps_04_g_99_q_n_ema, label="γ=0.99")

## display curves in one plot
# ax2 = ax.twinx()
# ax2.set_ylabel("R ")
# ax2.plot(eps_04_g_001_q_x_ema, eps_04_g_001_q_r_ema, label="γ=0.001", linestyle=line_style)
# ax2.plot(eps_04_g_02_q_x_ema, eps_04_g_02_q_r_ema, label="γ=0.2", linestyle=line_style)
# ax2.plot(eps_04_g_040_q_x_ema, eps_04_g_040_q_r_ema, label="γ=0.4", linestyle=line_style)
# ax2.plot(eps_04_g_055_q_x_ema, eps_04_g_055_q_r_ema, label="γ=0.55", linestyle=line_style)
# ax2.plot(eps_04_g_07_q_x_ema, eps_04_g_07_q_r_ema, label="γ=0.7", linestyle=line_style)
# ax2.plot(eps_04_g_85_q_x_ema, eps_04_g_85_q_r_ema, label="γ=0.85", linestyle=line_style)
# ax2.plot(eps_04_g_99_q_x_ema, eps_04_g_99_q_r_ema, label="γ=0.99", linestyle=line_style)

# ax.set_xlim((0,30000))
# ax.set_ylim((1.8,7))
ax.grid('on')
ax.plot()
lgd = fig.legend(loc=loc, bbox_to_anchor=(0.85,0.1), borderpad=1)
text = fig.text(-0.2,1.05, "", transform=ax.transAxes) 
plt.show()
fig.savefig("../plot/Q-γ_N_peak.jpg", bbox_extra_artists=(lgd,text), bbox_inches='tight', dpi=100)


#######################

new_figure()
fig2, ax2  = plt.subplots()
plt.title("Q Learning - R vs γ")
ax2.set_xlabel("episodes")
ax2.set_ylabel("R")
ax2.grid('on')
ax2.plot(eps_04_g_001_q_x_ema, eps_04_g_001_q_r_ema, label="γ=0.001")
ax2.plot(eps_04_g_02_q_x_ema, eps_04_g_02_q_r_ema, label="γ=0.2")
ax2.plot(eps_04_g_040_q_x_ema, eps_04_g_040_q_r_ema, label="γ=0.4")
ax2.plot(eps_04_g_055_q_x_ema, eps_04_g_055_q_r_ema, label="γ=0.55")
ax2.plot(eps_04_g_07_q_x_ema, eps_04_g_07_q_r_ema, label="γ=0.7")
ax2.plot(eps_04_g_85_q_x_ema, eps_04_g_85_q_r_ema, label="γ=0.85")
ax2.plot(eps_04_g_99_q_x_ema, eps_04_g_99_q_r_ema, label="γ=0.99")

# ax2.set_ylim((0.2, 1.02))
# ax2.set_xlim((0,50000))
bbox_to_anchor = (0.9,0.1)
lgd = fig2.legend(loc=loc, bbox_to_anchor=bbox_to_anchor, borderpad=1)
text = fig2.text(-0.2,1.05, "", transform=ax.transAxes) 
plt.show()
fig2.savefig("../plot/Q-γ_R_peak.jpg",bbox_extra_artists=(lgd,text), bbox_inches='tight', dpi=100)

# %% [markdown]
# ## Training curves with respect to beta

# %% [markdown]
# ### SARSA vs beta

# %%
new_figure()

fig, ax  = plt.subplots()
plt.title("SARSA - N vs β")
ax.set_xlabel("episodes")
ax.set_ylabel("N")

ax.plot(b_00100_g_07_s_x_ema, b_00100_g_07_s_n_ema, label="β=0.001")
# ax.plot(b_00200_g_07_s_x_ema, b_00200_g_07_s_n_ema, label="β=0.002")
# ax.plot(b_00300_g_07_s_x_ema, b_00300_g_07_s_n_ema, label="β=0.003")
ax.plot(b_00500_g_07_s_x_ema, b_00500_g_07_s_n_ema, label="β=0.005")
# ax.plot(b_00700_g_07_s_x_ema, b_00700_g_07_s_n_ema, label="β=0.007")
# ax.plot(b_00900_g_07_s_x_ema, b_00900_g_07_s_n_ema, label="β=0.009")
ax.plot(b_01000_g_07_s_x_ema, b_01000_g_07_s_n_ema, label="β=0.01")
# ax.plot(b_02000_g_07_s_x_ema, b_02000_g_07_s_n_ema, label="β=0.02")
ax.plot(b_04000_g_07_s_x_ema, b_04000_g_07_s_n_ema, label="β=0.04")
ax.plot(b_10000_g_07_s_x_ema, b_10000_g_07_s_n_ema, label="β=0.1")
ax.plot(b_20000_g_07_s_x_ema, b_20000_g_07_s_n_ema, label="β=0.2")
ax.plot(b_30000_g_07_s_x_ema, b_30000_g_07_s_n_ema, label="β=0.3")
# ax.set_xlim((0,30000))
# ax.set_ylim((2,5))
ax.grid('on')

# ax2 = ax.twinx()
# ax2.set_ylabel("R (- -)")
# ax2.plot(b_00100_g_07_s_x_ema, b_00100_g_07_s_r_ema, label="β=0.001", linestyle=line_style)
# ax2.plot(b_00200_g_07_s_x_ema, b_00200_g_07_s_r_ema, label="β=0.00200", linestyle=line_style)
# ax2.plot(b_00300_g_07_s_x_ema, b_00300_g_07_s_r_ema, label="β=0.00300", linestyle=line_style)
# ax2.plot(b_00500_g_07_s_x_ema, b_00500_g_07_s_r_ema, label="β=0.00500", linestyle=line_style)
# ax2.plot(b_00700_g_07_s_x_ema, b_00700_g_07_s_r_ema, label="β=0.00700", linestyle=line_style)
# ax2.plot(b_00900_g_07_s_x_ema, b_00900_g_07_s_r_ema, label="β=0.00900", linestyle=line_style)
# ax2.plot(b_01000_g_07_s_x_ema, b_01000_g_07_s_r_ema, label="β=0.01000", linestyle=line_style)
# ax2.plot(b_02000_g_07_s_x_ema, b_02000_g_07_s_r_ema, label="β=0.02000", linestyle=line_style)
# ax2.plot(b_04000_g_07_s_x_ema, b_04000_g_07_s_r_ema, label="β=0.04000", linestyle=line_style)
# ax2.plot(b_10000_g_07_s_x_ema, b_10000_g_07_s_r_ema, label="β=0.10000", linestyle=line_style)
# ax2.plot(b_30000_g_07_s_x_ema, b_30000_g_07_s_r_ema, label="β=0.30000", linestyle=line_style)

lgd = fig.legend(loc=loc, bbox_to_anchor=bbox_to_anchor, borderpad=1.3)
text = fig.text(-0.2,1.05, "", transform=ax.transAxes) 
plt.show()
fig.savefig("../plot/SARSA-beta_N.jpg", bbox_extra_artists=(lgd,text), bbox_inches='tight', dpi=100)

#######################################

fig2, ax2  = plt.subplots()
plt.title("SARSA - R vs β")
ax2.set_xlabel("episodes")
ax2.set_ylabel("N")
ax2.grid('on')
ax2.set_ylabel("R")
ax2.plot(b_00100_g_07_s_x_ema, b_00100_g_07_s_r_ema, label="β=0.001")
ax2.plot(b_00200_g_07_s_x_ema, b_00200_g_07_s_r_ema, label="β=0.002")
ax2.plot(b_00300_g_07_s_x_ema, b_00300_g_07_s_r_ema, label="β=0.003")
ax2.plot(b_00500_g_07_s_x_ema, b_00500_g_07_s_r_ema, label="β=0.005")
ax2.plot(b_00700_g_07_s_x_ema, b_00700_g_07_s_r_ema, label="β=0.007")
ax2.plot(b_00900_g_07_s_x_ema, b_00900_g_07_s_r_ema, label="β=0.009")
ax2.plot(b_01000_g_07_s_x_ema, b_01000_g_07_s_r_ema, label="β=0.01")
ax2.plot(b_02000_g_07_s_x_ema, b_02000_g_07_s_r_ema, label="β=0.02")
ax2.plot(b_04000_g_07_s_x_ema, b_04000_g_07_s_r_ema, label="β=0.04")
ax2.plot(b_10000_g_07_s_x_ema, b_10000_g_07_s_r_ema, label="β=0.1")
ax2.plot(b_20000_g_07_s_x_ema, b_20000_g_07_s_r_ema, label="β=0.2")
ax2.plot(b_30000_g_07_s_x_ema, b_30000_g_07_s_r_ema, label="β=0.3")
# ax2.set_xlim((0,30000))
# ax2.set_ylim((0.6,1.02))
lgd = fig2.legend(loc=loc, bbox_to_anchor=bbox_to_anchor, borderpad=1.3)
text = fig2.text(-0.2,1.05, "", transform=ax.transAxes) 
plt.show()
fig2.savefig("../plot/SARSA-r_β.jpg", bbox_extra_artists=(lgd,text), bbox_inches='tight', dpi=100)

# %% [markdown]
# ### Q learning vs beta

# %%
new_figure()

fig, ax  = plt.subplots()
plt.title("Q Learning - N vs β")
ax.set_xlabel("episodes")
ax.set_ylabel("N")
ax.plot(b_00100_g_07_q_x_ema, b_00100_g_07_q_n_ema, label="β=0.001")
# ax.plot(b_00200_g_07_q_x_ema, b_00200_g_07_q_n_ema, label="β=0.002")
# ax.plot(b_00300_g_07_q_x_ema, b_00300_g_07_q_n_ema, label="β=0.003")
ax.plot(b_00500_g_07_q_x_ema, b_00500_g_07_q_n_ema, label="β=0.005")
ax.plot(b_00700_g_07_q_x_ema, b_00700_g_07_q_n_ema, label="β=0.007")
# ax.plot(b_00900_g_07_q_x_ema, b_00900_g_07_q_n_ema, label="β=0.009")
ax.plot(b_01000_g_07_q_x_ema, b_01000_g_07_q_n_ema, label="β=0.01")
ax.plot(b_02000_g_07_q_x_ema, b_02000_g_07_q_n_ema, label="β=0.02")
# ax.plot(b_04000_g_07_q_x_ema, b_04000_g_07_q_n_ema, label="β=0.04")
ax.plot(b_10000_g_07_q_x_ema, b_10000_g_07_q_n_ema, label="β=0.1")
ax.plot(b_20000_g_07_q_x_ema, b_20000_g_07_q_n_ema, label="β=0.2")
ax.plot(b_30000_g_07_q_x_ema, b_30000_g_07_q_n_ema, label="β=0.3")
# ax.set_xlim((0, 30000))
# ax.set_ylim((2, 5))
ax.grid("on")
# ax2 =  ax.twinx()
# ax2.set_ylabel("R (- -)")
# ax2.plot(b_00100_g_07_q_x_ema, b_00100_g_07_q_r_ema, label="β=0.001", linestyle=line_style)
# ax2.plot(b_00200_g_07_q_x_ema, b_00200_g_07_q_r_ema, label="β=0.00200", linestyle=line_style)
# ax2.plot(b_00300_g_07_q_x_ema, b_00300_g_07_q_r_ema, label="β=0.00300", linestyle=line_style)
# ax2.plot(b_00500_g_07_q_x_ema, b_00500_g_07_q_r_ema, label="β=0.00500", linestyle=line_style)
# ax2.plot(b_00700_g_07_q_x_ema, b_00700_g_07_q_r_ema, label="β=0.00700", linestyle=line_style)
# ax2.plot(b_00900_g_07_q_x_ema, b_00900_g_07_q_r_ema, label="β=0.00900", linestyle=line_style)
# ax2.plot(b_01000_g_07_q_x_ema, b_01000_g_07_q_r_ema, label="β=0.01000", linestyle=line_style)
# ax2.plot(b_02000_g_07_q_x_ema, b_02000_g_07_q_r_ema, label="β=0.02000", linestyle=line_style)
# ax2.plot(b_04000_g_07_q_x_ema, b_04000_g_07_q_r_ema, label="β=0.04000", linestyle=line_style)
# ax2.plot(b_10000_g_07_q_x_ema, b_10000_g_07_q_r_ema, label="β=0.10000", linestyle=line_style)
# ax2.plot(b_30000_g_07_q_x_ema, b_30000_g_07_q_r_ema, label="β=0.30000", linestyle=line_style)

lgd = fig.legend(loc="upper right", borderpad=0.5)
text = fig.text(-0.2,1.05, "", transform=ax.transAxes) 
fig.savefig("../plot/Q-beta_N.jpg",bbox_extra_artists=(lgd,text), dpi=100)
plt.show()

fig2, ax2  = plt.subplots()
plt.title("Q Learning - R vs β")
ax2.set_xlabel("episodes")
ax2.set_ylabel("R")

ax2.plot(b_00100_g_07_q_x_ema, b_00100_g_07_q_r_ema, label="β=0.001")
ax2.plot(b_00200_g_07_q_x_ema, b_00200_g_07_q_r_ema, label="β=0.002")
ax2.plot(b_00300_g_07_q_x_ema, b_00300_g_07_q_r_ema, label="β=0.003")
ax2.plot(b_00500_g_07_q_x_ema, b_00500_g_07_q_r_ema, label="β=0.005")
ax2.plot(b_00700_g_07_q_x_ema, b_00700_g_07_q_r_ema, label="β=0.007")
ax2.plot(b_00900_g_07_q_x_ema, b_00900_g_07_q_r_ema, label="β=0.009")
ax2.plot(b_01000_g_07_q_x_ema, b_01000_g_07_q_r_ema, label="β=0.01")
ax2.plot(b_02000_g_07_q_x_ema, b_02000_g_07_q_r_ema, label="β=0.02")
ax2.plot(b_04000_g_07_q_x_ema, b_04000_g_07_q_r_ema, label="β=0.04")
ax2.plot(b_10000_g_07_q_x_ema, b_10000_g_07_q_r_ema, label="β=0.1")
ax2.plot(b_20000_g_07_q_x_ema, b_20000_g_07_q_r_ema, label="β=0.2")
ax2.plot(b_30000_g_07_q_x_ema, b_30000_g_07_q_r_ema, label="β=0.3")
ax2.set_xlim((0, 30000))
ax2.set_ylim((0.5, 1.02))
ax2.grid("on")
lgd = fig2.legend(loc=loc, bbox_to_anchor=bbox_to_anchor, borderpad=1.3)
text = fig2.text(-0.2,1.05, "", transform=ax.transAxes) 
plt.show()
fig2.savefig("../plot/Q-beta_R.jpg", bbox_extra_artists=(lgd,text), bbox_inches='tight', dpi=100)

# %% [markdown]
# ### Testing performance of all trained models

# %%
b_list=["0.001", "0.002", "0.003", "0.005", "0.007", "0.01","0.02","0.04","0.1","0.2","0.3"]
g_list=["0.001","0.2","0.40","0.55","0.7", "0.85", "0.99"]

b_q_r = [0.9972,0.99995,0.9999,0.9999,0.9999,0.9998,0.99975,0.99515,0.9962,1.0,0.99915]
g_q_r = [0.79955,0.87885,0.95455,0.9999,1.0,1.0,0.9994]
b_q_n = [2.0701,2.11465,2.2497,2.09455,2.39895,2.36945,2.6608,2.50115,2.4616,2.54245,2.6424]
g_q_n = [2.6294,2.07185,1.9563,1.97475,1.97625,2.01695,3.7342]

b_s_r = [0.9995,0.99595,1.0,0.99645,0.99975,1.0,0.99695,0.99995,0.99985,0.9999,0.99905]
g_s_r = [0.78395,0.84735,0.94965,0.99635,0.99975,1.0,0.99695]
b_s_n = [2.15485,2.36245,2.21885,2.13425,2.2511,2.27755,2.2737,2.30955,2.541,2.45305,2.39365]
g_s_n = [2.82705,2.01695,2.09255,2.1368, 2.0091, 2.0171,4.9889]

new_figure()
plt.title("Test Performance - Expected R versus β ")
plt.plot(b_list, b_q_r, label="Q")
plt.plot(b_list, b_s_r, label="SARSA")
plt.grid("on")
plt.legend()
plt.xlabel("R")
plt.ylabel("β")
plt.savefig("../plot/Test_R_β.jpg")

new_figure()
plt.title("Test Performance - Expected N versus β ")
plt.plot(b_list, b_q_n, label="Q")
plt.plot(b_list, b_s_n,label="SARSA")
plt.grid("on")
plt.legend()
plt.xlabel("N")
plt.ylabel("β")
plt.savefig("../plot/Test_N_β.jpg")

new_figure()
plt.title("Test Performance - Expected R versus γ ")
plt.plot(g_list, g_q_r, label="Q")
plt.plot(g_list, g_s_r,label="SARSA")
plt.grid("on")
plt.legend()
plt.xlabel("R")
plt.ylabel("γ")
plt.savefig("../plot/Test_R_γ.jpg")

new_figure()
plt.title("Test Performance - Expected N versus γ ")
plt.plot(g_list, g_q_n, label="Q")
plt.plot(g_list, g_s_n, label="SARSA")
plt.grid("on")
plt.legend()
plt.xlabel("N")
plt.ylabel("γ")
plt.savefig("../plot/Test_N_γ.jpg")

# %% [markdown]
# ### Train beta = 0.1 with 100k episodes

# %%
from data_gamma_07_eps_04_beta_10000_100k import *

(b_10000_g_07_100k_s_x_ema, b_10000_g_07_100k_s_r_ema) = EMA(gamma_07_eps_04_beta_10000_100k_SARSA_x_training_seq, gamma_07_eps_04_beta_10000_100k_SARSA_R_training_seq)
(b_10000_g_07_100k_q_x_ema, b_10000_g_07_100k_q_r_ema) = EMA(gamma_07_eps_04_beta_10000_100k_Q_Learning_x_training_seq, gamma_07_eps_04_beta_10000_100k_Q_Learning_R_training_seq)
(_, b_10000_g_07_100k_s_n_ema) = EMA(gamma_07_eps_04_beta_10000_100k_SARSA_x_training_seq, gamma_07_eps_04_beta_10000_100k_SARSA_N_training_seq)
(_, b_10000_g_07_100k_q_n_ema) = EMA(gamma_07_eps_04_beta_10000_100k_Q_Learning_x_training_seq, gamma_07_eps_04_beta_10000_100k_Q_Learning_N_training_seq)

new_figure()
plt.title("R - beta=0.1 max_episodes=100k")
plt.plot(b_10000_g_07_100k_s_x_ema,b_10000_g_07_100k_s_r_ema, label="SARSA")
plt.plot(b_10000_g_07_100k_q_x_ema,b_10000_g_07_100k_q_r_ema, label="Q")
plt.ylabel("R")
plt.xlabel("episodes")
plt.grid("on")
plt.legend()
plt.savefig("../plot/R - beta=0.1 max_episodes=100k.jpg")
new_figure()
plt.title("N steps - beta=0.1 max_episodes=100k")
plt.plot(b_10000_g_07_100k_s_x_ema,b_10000_g_07_100k_s_n_ema, label="SARSA")
plt.plot(b_10000_g_07_100k_q_x_ema,b_10000_g_07_100k_q_n_ema, label="Q")
plt.ylabel("N")
plt.xlabel("episodes")
plt.grid("on")
plt.legend()
plt.savefig("../plot/N steps - beta=0.1 max_episodes=100k.jpg")
