# %%
import matplotlib.pyplot as plt

## exp moving average
def EMA(x, y):
    k = 4 / len(x)
    ema_seq = []
    ema_prev = 0
    for t in range(0, len(x)):
        y_t = y[t] * k + ema_prev * (1 - k)
        ema_prev = y_t
        ema_seq.append(y_t)
    return (x, ema_seq)

# %%
from data_no_tuning import *

(nt_s_ema_x, nt_s_r_ema) = EMA(no_tuning_SARSA_x_training_seq, no_tuning_SARSA_R_training_seq)
(nt_q_ema_x, nt_q_r_ema) = EMA(no_tuning_Q_Learning_x_training_seq, no_tuning_Q_Learning_R_training_seq)
(nt_dq_ema_x, nt_dq_r_ema) = EMA(no_tuning_Double_Q_x_training_seq, no_tuning_Double_Q_R_training_seq)
(_, nt_s_n_ema) = EMA(no_tuning_SARSA_x_training_seq, no_tuning_SARSA_N_training_seq)
(_, nt_q_n_ema) = EMA(no_tuning_Q_Learning_x_training_seq, no_tuning_Q_Learning_N_training_seq)
(_, nt_dq_n_ema) = EMA(no_tuning_Double_Q_x_training_seq, no_tuning_Double_Q_N_training_seq)

from data_gamma_070 import *
from data_gamma_080 import *
from data_gamma_090 import *
from data_gamma_098 import *

(g_098_s_ema_x, g_098_s_r_ema) = EMA(gamma_098_SARSA_x_training_seq, gamma_098_SARSA_R_training_seq)
(g_098_q_ema_x, g_098_q_r_ema) = EMA(gamma_098_Q_Learning_x_training_seq, gamma_098_Q_Learning_R_training_seq)
(g_098_dq_ema_x, g_098_dq_r_ema) = EMA(gamma_098_Double_Q_x_training_seq, gamma_098_Double_Q_R_training_seq)
(_, g_098_s_n_ema) = EMA(gamma_098_SARSA_x_training_seq, gamma_098_SARSA_N_training_seq)
(_, g_098_q_n_ema) = EMA(gamma_098_Q_Learning_x_training_seq, gamma_098_Q_Learning_N_training_seq)
(_, g_098_dq_n_ema) = EMA(gamma_098_Double_Q_x_training_seq, gamma_098_Double_Q_N_training_seq)

(g_070_s_ema_x, g_070_s_r_ema) = EMA(gamma_070_SARSA_x_training_seq, gamma_070_SARSA_R_training_seq)
(g_070_q_ema_x, g_070_q_r_ema) = EMA(gamma_070_Q_Learning_x_training_seq, gamma_070_Q_Learning_R_training_seq)
(g_070_dq_ema_x, g_070_dq_r_ema) = EMA(gamma_070_Double_Q_x_training_seq, gamma_070_Double_Q_R_training_seq)
(_, g_070_s_n_ema) = EMA(gamma_070_SARSA_x_training_seq, gamma_070_SARSA_N_training_seq)
(_, g_070_q_n_ema) = EMA(gamma_070_Q_Learning_x_training_seq, gamma_070_Q_Learning_N_training_seq)
(_, g_070_dq_n_ema) = EMA(gamma_070_Double_Q_x_training_seq, gamma_070_Double_Q_N_training_seq)

(g_080_s_ema_x, g_080_s_r_ema) = EMA(gamma_080_SARSA_x_training_seq, gamma_080_SARSA_R_training_seq)
(g_080_q_ema_x, g_080_q_r_ema) = EMA(gamma_080_Q_Learning_x_training_seq, gamma_080_Q_Learning_R_training_seq)
(g_080_dq_ema_x, g_080_dq_r_ema) = EMA(gamma_080_Double_Q_x_training_seq, gamma_080_Double_Q_R_training_seq)
(_, g_080_s_n_ema) = EMA(gamma_080_SARSA_x_training_seq, gamma_080_SARSA_N_training_seq)
(_, g_080_q_n_ema) = EMA(gamma_080_Q_Learning_x_training_seq, gamma_080_Q_Learning_N_training_seq)
(_, g_080_dq_n_ema) = EMA(gamma_080_Double_Q_x_training_seq, gamma_080_Double_Q_N_training_seq)

(g_090_s_ema_x, g_090_s_r_ema) = EMA(gamma_090_SARSA_x_training_seq, gamma_090_SARSA_R_training_seq)
(g_090_q_ema_x, g_090_q_r_ema) = EMA(gamma_090_Q_Learning_x_training_seq, gamma_090_Q_Learning_R_training_seq)
(g_090_dq_ema_x, g_090_dq_r_ema) = EMA(gamma_090_Double_Q_x_training_seq, gamma_090_Double_Q_R_training_seq)
(_, g_090_s_n_ema) = EMA(gamma_090_SARSA_x_training_seq, gamma_090_SARSA_N_training_seq)
(_, g_090_q_n_ema) = EMA(gamma_090_Q_Learning_x_training_seq, gamma_090_Q_Learning_N_training_seq)
(_, g_090_dq_n_ema) = EMA(gamma_090_Double_Q_x_training_seq, gamma_090_Double_Q_N_training_seq)

from data_beta_00010 import *
from data_beta_00020 import *
from data_beta_00030 import *
from data_beta_00050 import *
from data_beta_00100 import *
(b_00030_s_ema_x, b_00030_s_r_ema) = EMA(beta_00030_SARSA_x_training_seq, beta_00030_SARSA_R_training_seq)
(b_00030_q_ema_x, b_00030_q_r_ema) = EMA(beta_00030_Q_Learning_x_training_seq, beta_00030_Q_Learning_R_training_seq)
(b_00030_dq_ema_x, b_00030_dq_r_ema) = EMA(beta_00030_Double_Q_x_training_seq, beta_00030_Double_Q_R_training_seq)
(_, b_00030_s_n_ema) = EMA(beta_00030_SARSA_x_training_seq, beta_00030_SARSA_N_training_seq)
(_, b_00030_q_n_ema) = EMA(beta_00030_Q_Learning_x_training_seq, beta_00030_Q_Learning_N_training_seq)
(_, b_00030_dq_n_ema) = EMA(beta_00030_Double_Q_x_training_seq, beta_00030_Double_Q_N_training_seq)

(b_00020_s_ema_x, b_00020_s_r_ema) = EMA(beta_00020_SARSA_x_training_seq, beta_00020_SARSA_R_training_seq)
(b_00020_q_ema_x, b_00020_q_r_ema) = EMA(beta_00020_Q_Learning_x_training_seq, beta_00020_Q_Learning_R_training_seq)
(b_00020_dq_ema_x, b_00020_dq_r_ema) = EMA(beta_00020_Double_Q_x_training_seq, beta_00020_Double_Q_R_training_seq)
(_, b_00020_s_n_ema) = EMA(beta_00020_SARSA_x_training_seq, beta_00020_SARSA_N_training_seq)
(_, b_00020_q_n_ema) = EMA(beta_00020_Q_Learning_x_training_seq, beta_00020_Q_Learning_N_training_seq)
(_, b_00020_dq_n_ema) = EMA(beta_00020_Double_Q_x_training_seq, beta_00020_Double_Q_N_training_seq)

(b_00010_s_ema_x, b_00010_s_r_ema) = EMA(beta_00010_SARSA_x_training_seq, beta_00010_SARSA_R_training_seq)
(b_00010_q_ema_x, b_00010_q_r_ema) = EMA(beta_00010_Q_Learning_x_training_seq, beta_00010_Q_Learning_R_training_seq)
(b_00010_dq_ema_x, b_00010_dq_r_ema) = EMA(beta_00010_Double_Q_x_training_seq, beta_00010_Double_Q_R_training_seq)
(_, b_00010_s_n_ema) = EMA(beta_00010_SARSA_x_training_seq, beta_00010_SARSA_N_training_seq)
(_, b_00010_q_n_ema) = EMA(beta_00010_Q_Learning_x_training_seq, beta_00010_Q_Learning_N_training_seq)
(_, b_00010_dq_n_ema) = EMA(beta_00010_Double_Q_x_training_seq, beta_00010_Double_Q_N_training_seq)

(b_00050_s_ema_x, b_00050_s_r_ema) = EMA(beta_00050_SARSA_x_training_seq, beta_00050_SARSA_R_training_seq)
(b_00050_q_ema_x, b_00050_q_r_ema) = EMA(beta_00050_Q_Learning_x_training_seq, beta_00050_Q_Learning_R_training_seq)
(b_00050_dq_ema_x, b_00050_dq_r_ema) = EMA(beta_00050_Double_Q_x_training_seq, beta_00050_Double_Q_R_training_seq)
(_, b_00050_s_n_ema) = EMA(beta_00050_SARSA_x_training_seq, beta_00050_SARSA_N_training_seq)
(_, b_00050_q_n_ema) = EMA(beta_00050_Q_Learning_x_training_seq, beta_00050_Q_Learning_N_training_seq)
(_, b_00050_dq_n_ema) = EMA(beta_00050_Double_Q_x_training_seq, beta_00050_Double_Q_N_training_seq)


(b_00100_s_ema_x, b_00100_s_r_ema) = EMA(beta_00100_SARSA_x_training_seq, beta_00100_SARSA_R_training_seq)
(b_00100_q_ema_x, b_00100_q_r_ema) = EMA(beta_00100_Q_Learning_x_training_seq, beta_00100_Q_Learning_R_training_seq)
(b_00100_dq_ema_x, b_00100_dq_r_ema) = EMA(beta_00100_Double_Q_x_training_seq, beta_00100_Double_Q_R_training_seq)
(_, b_00100_s_n_ema) = EMA(beta_00100_SARSA_x_training_seq, beta_00100_SARSA_N_training_seq)
(_, b_00100_q_n_ema) = EMA(beta_00100_Q_Learning_x_training_seq, beta_00100_Q_Learning_N_training_seq)
(_, b_00100_dq_n_ema) = EMA(beta_00100_Double_Q_x_training_seq, beta_00100_Double_Q_N_training_seq)


from data_eps_05_beta_00005 import *
from data_eps_05_beta_00050 import *
from data_eps_05_beta_00100 import *
from data_eps_05_beta_00200 import *
from data_eps_09_beta_00100 import *
from data_eps_09_beta_00200 import *
from data_eps_09_beta_00500 import *


from data_eps_05_gamma_05 import *
from data_eps_05_gamma_08 import *
from data_eps_05_gamma_99 import *

(eps_05_b_00005_s_ema_x, eps_05_b_00005_s_r_ema) = EMA(eps_05_beta_00005_SARSA_x_training_seq, eps_05_beta_00005_SARSA_R_training_seq)
(eps_05_b_00005_q_ema_x, eps_05_b_00005_q_r_ema) = EMA(eps_05_beta_00005_Q_Learning_x_training_seq, eps_05_beta_00005_Q_Learning_R_training_seq)
(eps_05_b_00005_dq_ema_x, eps_05_b_00005_dq_r_ema) = EMA(eps_05_beta_00005_Double_Q_x_training_seq, eps_05_beta_00005_Double_Q_R_training_seq)
(_, eps_05_b_00005_s_n_ema) = EMA(eps_05_beta_00005_SARSA_x_training_seq, eps_05_beta_00005_SARSA_N_training_seq)
(_, eps_05_b_00005_q_n_ema) = EMA(eps_05_beta_00005_Q_Learning_x_training_seq, eps_05_beta_00005_Q_Learning_N_training_seq)
(_, eps_05_b_00005_dq_n_ema) = EMA(eps_05_beta_00005_Double_Q_x_training_seq, eps_05_beta_00005_Double_Q_N_training_seq)

(eps_05_b_00050_s_ema_x, eps_05_b_00050_s_r_ema) = EMA(eps_05_beta_00050_SARSA_x_training_seq, eps_05_beta_00050_SARSA_R_training_seq)
(eps_05_b_00050_q_ema_x, eps_05_b_00050_q_r_ema) = EMA(eps_05_beta_00050_Q_Learning_x_training_seq, eps_05_beta_00050_Q_Learning_R_training_seq)
(eps_05_b_00050_dq_ema_x, eps_05_b_00050_dq_r_ema) = EMA(eps_05_beta_00050_Double_Q_x_training_seq, eps_05_beta_00050_Double_Q_R_training_seq)
(_, eps_05_b_00050_s_n_ema) = EMA(eps_05_beta_00050_SARSA_x_training_seq, eps_05_beta_00050_SARSA_N_training_seq)
(_, eps_05_b_00050_q_n_ema) = EMA(eps_05_beta_00050_Q_Learning_x_training_seq, eps_05_beta_00050_Q_Learning_N_training_seq)
(_, eps_05_b_00050_dq_n_ema) = EMA(eps_05_beta_00050_Double_Q_x_training_seq, eps_05_beta_00050_Double_Q_N_training_seq)

(eps_05_b_00100_s_ema_x, eps_05_b_00100_s_r_ema) = EMA(eps_05_beta_00100_SARSA_x_training_seq, eps_05_beta_00100_SARSA_R_training_seq)
(eps_05_b_00100_q_ema_x, eps_05_b_00100_q_r_ema) = EMA(eps_05_beta_00100_Q_Learning_x_training_seq, eps_05_beta_00100_Q_Learning_R_training_seq)
(eps_05_b_00100_dq_ema_x, eps_05_b_00100_dq_r_ema) = EMA(eps_05_beta_00100_Double_Q_x_training_seq, eps_05_beta_00100_Double_Q_R_training_seq)
(_, eps_05_b_00100_s_n_ema) = EMA(eps_05_beta_00100_SARSA_x_training_seq, eps_05_beta_00100_SARSA_N_training_seq)
(_, eps_05_b_00100_q_n_ema) = EMA(eps_05_beta_00100_Q_Learning_x_training_seq, eps_05_beta_00100_Q_Learning_N_training_seq)
(_, eps_05_b_00100_dq_n_ema) = EMA(eps_05_beta_00100_Double_Q_x_training_seq, eps_05_beta_00100_Double_Q_N_training_seq)

(eps_05_b_00200_s_ema_x, eps_05_b_00200_s_r_ema) = EMA(eps_05_beta_00200_SARSA_x_training_seq, eps_05_beta_00200_SARSA_R_training_seq)
(eps_05_b_00200_q_ema_x, eps_05_b_00200_q_r_ema) = EMA(eps_05_beta_00200_Q_Learning_x_training_seq, eps_05_beta_00200_Q_Learning_R_training_seq)
(eps_05_b_00200_dq_ema_x, eps_05_b_00200_dq_r_ema) = EMA(eps_05_beta_00200_Double_Q_x_training_seq, eps_05_beta_00200_Double_Q_R_training_seq)
(_, eps_05_b_00200_s_n_ema) = EMA(eps_05_beta_00200_SARSA_x_training_seq, eps_05_beta_00200_SARSA_N_training_seq)
(_, eps_05_b_00200_q_n_ema) = EMA(eps_05_beta_00200_Q_Learning_x_training_seq, eps_05_beta_00200_Q_Learning_N_training_seq)
(_, eps_05_b_00200_dq_n_ema) = EMA(eps_05_beta_00200_Double_Q_x_training_seq, eps_05_beta_00200_Double_Q_N_training_seq)


(eps_09_b_00100_s_ema_x, eps_09_b_00100_s_r_ema) = EMA(eps_09_beta_00100_SARSA_x_training_seq, eps_09_beta_00100_SARSA_R_training_seq)
(eps_09_b_00100_q_ema_x, eps_09_b_00100_q_r_ema) = EMA(eps_09_beta_00100_Q_Learning_x_training_seq, eps_09_beta_00100_Q_Learning_R_training_seq)
(eps_09_b_00100_dq_ema_x, eps_09_b_00100_dq_r_ema) = EMA(eps_09_beta_00100_Double_Q_x_training_seq, eps_09_beta_00100_Double_Q_R_training_seq)
(_, eps_09_b_00100_s_n_ema) = EMA(eps_09_beta_00100_SARSA_x_training_seq, eps_09_beta_00100_SARSA_N_training_seq)
(_, eps_09_b_00100_q_n_ema) = EMA(eps_09_beta_00100_Q_Learning_x_training_seq, eps_09_beta_00100_Q_Learning_N_training_seq)
(_, eps_09_b_00100_dq_n_ema) = EMA(eps_09_beta_00100_Double_Q_x_training_seq, eps_09_beta_00100_Double_Q_N_training_seq)

(eps_09_b_00200_s_ema_x, eps_09_b_00200_s_r_ema) = EMA(eps_09_beta_00200_SARSA_x_training_seq, eps_09_beta_00200_SARSA_R_training_seq)
(eps_09_b_00200_q_ema_x, eps_09_b_00200_q_r_ema) = EMA(eps_09_beta_00200_Q_Learning_x_training_seq, eps_09_beta_00200_Q_Learning_R_training_seq)
(eps_09_b_00200_dq_ema_x, eps_09_b_00200_dq_r_ema) = EMA(eps_09_beta_00200_Double_Q_x_training_seq, eps_09_beta_00200_Double_Q_R_training_seq)
(_, eps_09_b_00200_s_n_ema) = EMA(eps_09_beta_00200_SARSA_x_training_seq, eps_09_beta_00200_SARSA_N_training_seq)
(_, eps_09_b_00200_q_n_ema) = EMA(eps_09_beta_00200_Q_Learning_x_training_seq, eps_09_beta_00200_Q_Learning_N_training_seq)
(_, eps_09_b_00200_dq_n_ema) = EMA(eps_09_beta_00200_Double_Q_x_training_seq, eps_09_beta_00200_Double_Q_N_training_seq)

(eps_09_b_00500_s_ema_x, eps_09_b_00500_s_r_ema) = EMA(eps_09_beta_00500_SARSA_x_training_seq, eps_09_beta_00500_SARSA_R_training_seq)
(eps_09_b_00500_q_ema_x, eps_09_b_00500_q_r_ema) = EMA(eps_09_beta_00500_Q_Learning_x_training_seq, eps_09_beta_00500_Q_Learning_R_training_seq)
(eps_09_b_00500_dq_ema_x, eps_09_b_00500_dq_r_ema) = EMA(eps_09_beta_00500_Double_Q_x_training_seq, eps_09_beta_00500_Double_Q_R_training_seq)
(_, eps_09_b_00500_s_n_ema) = EMA(eps_09_beta_00500_SARSA_x_training_seq, eps_09_beta_00500_SARSA_N_training_seq)
(_, eps_09_b_00500_q_n_ema) = EMA(eps_09_beta_00500_Q_Learning_x_training_seq, eps_09_beta_00500_Q_Learning_N_training_seq)
(_, eps_09_b_00500_dq_n_ema) = EMA(eps_09_beta_00500_Double_Q_x_training_seq, eps_09_beta_00500_Double_Q_N_training_seq)

(eps_05_gamma_05_s_ema_x, eps_05_gamma_05_s_r_ema) = EMA(eps_05_gamma_05_SARSA_x_training_seq, eps_05_gamma_05_SARSA_R_training_seq)
(eps_05_gamma_05_q_ema_x, eps_05_gamma_05_q_r_ema) = EMA(eps_05_gamma_05_Q_Learning_x_training_seq, eps_05_gamma_05_Q_Learning_R_training_seq)
(eps_05_gamma_05_dq_ema_x, eps_05_gamma_05_dq_r_ema) = EMA(eps_05_gamma_05_Double_Q_x_training_seq, eps_05_gamma_05_Double_Q_R_training_seq)
(_, eps_05_gamma_05_s_n_ema) = EMA(eps_05_gamma_05_SARSA_x_training_seq, eps_05_gamma_05_SARSA_N_training_seq)
(_, eps_05_gamma_05_q_n_ema) = EMA(eps_05_gamma_05_Q_Learning_x_training_seq, eps_05_gamma_05_Q_Learning_N_training_seq)
(_, eps_05_gamma_05_dq_n_ema) = EMA(eps_05_gamma_05_Double_Q_x_training_seq, eps_05_gamma_05_Double_Q_N_training_seq)

(eps_05_gamma_08_s_ema_x, eps_05_gamma_08_s_r_ema) = EMA(eps_05_gamma_08_SARSA_x_training_seq, eps_05_gamma_08_SARSA_R_training_seq)
(eps_05_gamma_08_q_ema_x, eps_05_gamma_08_q_r_ema) = EMA(eps_05_gamma_08_Q_Learning_x_training_seq, eps_05_gamma_08_Q_Learning_R_training_seq)
(eps_05_gamma_08_dq_ema_x, eps_05_gamma_08_dq_r_ema) = EMA(eps_05_gamma_08_Double_Q_x_training_seq, eps_05_gamma_08_Double_Q_R_training_seq)
(_, eps_05_gamma_08_s_n_ema) = EMA(eps_05_gamma_08_SARSA_x_training_seq, eps_05_gamma_08_SARSA_N_training_seq)
(_, eps_05_gamma_08_q_n_ema) = EMA(eps_05_gamma_08_Q_Learning_x_training_seq, eps_05_gamma_08_Q_Learning_N_training_seq)
(_, eps_05_gamma_08_dq_n_ema) = EMA(eps_05_gamma_08_Double_Q_x_training_seq, eps_05_gamma_08_Double_Q_N_training_seq)

(eps_05_gamma_99_s_ema_x, eps_05_gamma_99_s_r_ema) = EMA(eps_05_gamma_99_SARSA_x_training_seq, eps_05_gamma_99_SARSA_R_training_seq)
(eps_05_gamma_99_q_ema_x, eps_05_gamma_99_q_r_ema) = EMA(eps_05_gamma_99_Q_Learning_x_training_seq, eps_05_gamma_99_Q_Learning_R_training_seq)
(eps_05_gamma_99_dq_ema_x, eps_05_gamma_99_dq_r_ema) = EMA(eps_05_gamma_99_Double_Q_x_training_seq, eps_05_gamma_99_Double_Q_R_training_seq)
(_, eps_05_gamma_99_s_n_ema) = EMA(eps_05_gamma_99_SARSA_x_training_seq, eps_05_gamma_99_SARSA_N_training_seq)
(_, eps_05_gamma_99_q_n_ema) = EMA(eps_05_gamma_99_Q_Learning_x_training_seq, eps_05_gamma_99_Q_Learning_N_training_seq)
(_, eps_05_gamma_99_dq_n_ema) = EMA(eps_05_gamma_99_Double_Q_x_training_seq, eps_05_gamma_99_Double_Q_N_training_seq)

# %%
plt.figure(1)
plt.title("Initial - R EMA")
plt.plot(nt_q_ema_x, nt_q_r_ema, label="Q Learning")
plt.plot(nt_s_ema_x, nt_s_r_ema, label="SARSA")
plt.plot(nt_dq_ema_x, nt_dq_r_ema, label="Double Q")
plt.legend()
plt.xlabel("episodes")
plt.ylabel("R")


#plt.savefig("plot/initial_r_ema.jpg")
# Out:
# Text(0, 0.5, 'R')

# %%
plt.figure(2)
plt.title("inital - N steps EMA")
plt.plot(nt_q_ema_x, nt_q_n_ema, label="Q Learning")
plt.plot(nt_s_ema_x, nt_s_n_ema, label="SARSA")
plt.plot(nt_dq_ema_x, nt_dq_n_ema, label="Double Q")
plt.legend()
plt.xlabel("episodes")
plt.ylabel("N steps")

#plt.savefig("plot/initial_n_ema.jpg")
# Out:
# Text(0, 0.5, 'N steps')

# %%
from data_nt_early_stop import *

(nt_s_ema_x, nt_s_r_ema) = EMA(nt_early_stop_SARSA_x_training_seq, nt_early_stop_SARSA_R_training_seq)
(nt_q_ema_x, nt_q_r_ema) = EMA(nt_early_stop_Q_Learning_x_training_seq, nt_early_stop_Q_Learning_R_training_seq)
(nt_dq_ema_x, nt_dq_r_ema) = EMA(nt_early_stop_Double_Q_x_training_seq, nt_early_stop_Double_Q_R_training_seq)
(_, nt_s_n_ema) = EMA(nt_early_stop_SARSA_x_training_seq, nt_early_stop_SARSA_N_training_seq)
(_, nt_q_n_ema) = EMA(nt_early_stop_Q_Learning_x_training_seq, nt_early_stop_Q_Learning_N_training_seq)
(_, nt_dq_n_ema) = EMA(nt_early_stop_Double_Q_x_training_seq, nt_early_stop_Double_Q_N_training_seq)

# %%
plt.figure(3)
plt.title("Q learning - R EMA")
plt.plot(g_098_q_ema_x, g_098_q_r_ema, label="γ=0.98")
plt.plot(g_090_q_ema_x, g_090_q_r_ema, label="γ=0.9")
plt.plot(nt_q_ema_x , nt_q_r_ema , label="γ=0.85(initial)")
plt.plot(g_080_q_ema_x, g_080_q_r_ema, label="γ=0.8")
plt.plot(g_070_q_ema_x, g_070_q_r_ema, label="γ=0.7")
plt.legend()
plt.xlabel("episodes")
plt.ylabel("R")

#plt.savefig("plot/gamma_q_r_ema.jpg")

plt.figure(4)
plt.title("Q learning - N steps EMA")
plt.plot(g_098_q_ema_x, g_098_q_n_ema, label="γ=0.98")
plt.plot(g_090_q_ema_x, g_090_q_n_ema, label="γ=0.9")
plt.plot(nt_q_ema_x , nt_q_n_ema , label="γ=0.85(initial)")
plt.plot(g_080_q_ema_x, g_080_q_n_ema, label="γ=0.8")
plt.plot(g_070_q_ema_x, g_070_q_n_ema, label="γ=0.7")
plt.legend()
plt.xlabel("episodes")
plt.ylabel("N steps")

#plt.savefig("plot/gamma_q_n_ema.jpg")
# Out:
# Text(0, 0.5, 'N steps')

# %%
plt.figure(11)
plt.title("Double Q learning - R EMA")
plt.plot(g_098_dq_ema_x, g_098_dq_r_ema, label="γ=0.98")
plt.plot(g_090_dq_ema_x, g_090_dq_r_ema, label="γ=0.9")
plt.plot(nt_dq_ema_x , nt_dq_r_ema , label="γ=0.85(initial)")
plt.plot(g_080_dq_ema_x, g_080_dq_r_ema, label="γ=0.8")
plt.plot(g_070_dq_ema_x, g_070_dq_r_ema, label="γ=0.7")
plt.legend()
plt.xlabel("episodes")
plt.ylabel("R")

#plt.savefig("plot/gamma_dq_r_ema.jpg")

plt.figure(12)
plt.title("Double Q learning - N steps EMA")
plt.plot(g_098_dq_ema_x, g_098_dq_n_ema, label="γ=0.98")
plt.plot(g_090_dq_ema_x, g_090_dq_n_ema, label="γ=0.9")
plt.plot(nt_dq_ema_x , nt_dq_n_ema , label="γ=0.85(initial)")
plt.plot(g_080_dq_ema_x, g_080_dq_n_ema, label="γ=0.8")
plt.plot(g_070_dq_ema_x, g_070_dq_n_ema, label="γ=0.7")

plt.legend()
plt.xlabel("episodes")
plt.ylabel("N steps")

#plt.savefig("plot/gamma_dq_n_ema.jpg")
# Out:
# Text(0, 0.5, 'N steps')

# %%
plt.figure(11)
plt.title("SARSA learning - R EMA")
plt.plot(g_098_s_ema_x, g_098_s_r_ema, label="γ=0.98")
plt.plot(g_090_s_ema_x, g_090_s_r_ema, label="γ=0.9")
plt.plot(nt_s_ema_x , nt_s_r_ema , label="γ=0.85(initial)")
plt.plot(g_080_s_ema_x, g_080_s_r_ema, label="γ=0.8")
plt.plot(g_070_s_ema_x, g_070_s_r_ema, label="γ=0.7")
plt.legend()
plt.xlabel("episodes")
plt.ylabel("R")

#plt.savefig("plot/gamma_s_r_ema.jpg")

plt.figure(12)
plt.title("SARSA learning - N steps EMA")
plt.plot(g_098_s_ema_x, g_098_s_n_ema, label="γ=0.98")
plt.plot(g_090_s_ema_x, g_090_s_n_ema, label="γ=0.9")
plt.plot(nt_s_ema_x , nt_s_n_ema , label="γ=0.85(initial)")
plt.plot(g_080_s_ema_x, g_080_s_n_ema, label="γ=0.8")
plt.plot(g_070_s_ema_x, g_070_s_n_ema, label="γ=0.7")

plt.legend()
plt.xlabel("episodes")
plt.ylabel("N steps")

#plt.savefig("plot/gamma_s_n_ema.jpg")
# Out:
# Text(0, 0.5, 'N steps')

# %%
plt.figure(10)
plt.title("SARSA learning - R EMA")
plt.plot(nt_s_ema_x , nt_s_r_ema , label="β=0.00005(initial)")
plt.plot(b_00010_s_ema_x, b_00010_s_r_ema, label="β=0.00010")
plt.plot(b_00020_s_ema_x, b_00020_s_r_ema, label="β=0.00020")
plt.plot(b_00030_s_ema_x, b_00030_s_r_ema, label="β=0.00030")
plt.plot(b_00050_s_ema_x, b_00050_s_r_ema, label="β=0.00050")
plt.plot(b_00100_s_ema_x, b_00100_s_r_ema, label="β=0.00100")
plt.legend()
plt.xlabel("episodes")
plt.ylabel("R")


#plt.savefig("plot/beta_s_r_ema.jpg")

plt.figure(9)
plt.title("SARSA learning - N steps EMA")
plt.plot(nt_s_ema_x , nt_s_n_ema , label="β=0.0005(initial)")
plt.plot(b_00010_s_ema_x, b_00010_s_n_ema, label="β=0.00010")
plt.plot(b_00020_s_ema_x, b_00020_s_n_ema, label="β=0.00020")
plt.plot(b_00030_s_ema_x, b_00030_s_n_ema, label="β=0.00030")
plt.plot(b_00050_s_ema_x, b_00050_s_n_ema, label="β=0.00050")
plt.plot(b_00100_s_ema_x, b_00100_s_n_ema, label="β=0.00100")
plt.legend()
plt.xlabel("episodes")
plt.ylabel("N steps")


#plt.savefig("plot/beta_s_n_ema.jpg")
# Out:
# Text(0, 0.5, 'N steps')

# %%
plt.figure(13)
plt.title("Q learning - R EMA")
plt.plot(nt_q_ema_x , nt_q_r_ema , label="β=0.00005(initial)")
plt.plot(b_00010_q_ema_x, b_00010_q_r_ema, label="β=0.00010")
plt.plot(b_00020_q_ema_x, b_00020_q_r_ema, label="β=0.00020")
plt.plot(b_00030_q_ema_x, b_00030_q_r_ema, label="β=0.00030")
plt.plot(b_00050_q_ema_x, b_00050_q_r_ema, label="β=0.00050")
plt.plot(b_00100_q_ema_x, b_00100_q_r_ema, label="β=0.00100")
plt.legend()
plt.xlabel("episodes")
plt.ylabel("R")


#plt.savefig("plot/beta_q_r_ema.jpg")

plt.figure(14)
plt.title("Q learning - N steps EMA")
plt.plot(nt_q_ema_x , nt_q_n_ema , label="β=0.0005(initial)")
plt.plot(b_00010_q_ema_x, b_00010_q_n_ema, label="β=0.00010")
plt.plot(b_00020_q_ema_x, b_00020_q_n_ema, label="β=0.00020")
plt.plot(b_00030_q_ema_x, b_00030_q_n_ema, label="β=0.00030")
plt.plot(b_00050_q_ema_x, b_00050_q_n_ema, label="β=0.00050")
plt.plot(b_00100_q_ema_x, b_00100_q_n_ema, label="β=0.00100")
plt.legend()
plt.xlabel("episodes")
plt.ylabel("N steps")


#plt.savefig("plot/beta_q_n_ema.jpg")
# Out:
# Text(0, 0.5, 'N steps')

# %%
plt.figure(15)
plt.title("Double Q - R EMA")
plt.plot(nt_dq_ema_x , nt_dq_r_ema , label="β=0.00005(initial)")
plt.plot(b_00010_dq_ema_x, b_00010_dq_r_ema, label="β=0.00010")
plt.plot(b_00020_dq_ema_x, b_00020_dq_r_ema, label="β=0.00020")
plt.plot(b_00030_dq_ema_x, b_00030_dq_r_ema, label="β=0.00030")
plt.plot(b_00050_dq_ema_x, b_00050_dq_r_ema, label="β=0.00050")
plt.plot(b_00100_dq_ema_x, b_00100_dq_r_ema, label="β=0.00100")
plt.legend()
plt.xlabel("episodes")
plt.ylabel("R")


#plt.savefig("plot/beta_dq_r_ema.jpg")

plt.figure(16)
plt.title("Double Q learning - N steps EMA")
plt.plot(nt_dq_ema_x , nt_dq_n_ema , label="β=0.00005(initial)")
plt.plot(b_00010_dq_ema_x, b_00010_dq_n_ema, label="β=0.00010")
plt.plot(b_00020_dq_ema_x, b_00020_dq_n_ema, label="β=0.00020")
plt.plot(b_00030_dq_ema_x, b_00030_dq_n_ema, label="β=0.00030")
plt.plot(b_00050_dq_ema_x, b_00050_dq_n_ema, label="β=0.00050")
plt.plot(b_00100_dq_ema_x, b_00100_dq_n_ema, label="β=0.00100")
plt.legend()
plt.xlabel("episodes")
plt.ylabel("N steps")


#plt.savefig("plot/beta_dq_n_ema.jpg")
# Out:
# Text(0, 0.5, 'N steps')

# %%
import numpy as np
idx = 20
def new_figure():
    global idx
    idx +=1
    return plt.figure(idx)

N_ep = 100000
def get_N_percentage(ep_s):
    x_array = np.asarray(ep_s)
    return x_array/N_ep * 100
get_N_percentage(nt_q_ema_x)

def get_eps_s(epsilon_0, beta, ep_s):
    x_array = np.asarray(ep_s)
    return epsilon_0 / (1 + beta * x_array)
get_eps_s(0.5, 0.00005, nt_q_ema_x)
# Out:
# array([0.5       , 0.499975  , 0.49995   , ..., 0.19231509, 0.19231139,
#        0.19230769])

# %%
new_figure()
plt.title("Q - R EMA")
plt.plot(eps_05_b_00005_q_ema_x, eps_05_b_00005_q_r_ema , label="Ɛ=0.5 β=0.00005")
plt.plot(eps_05_b_00050_q_ema_x, eps_05_b_00050_q_r_ema, label="Ɛ=0.5 β=0.00050")
plt.plot(eps_05_b_00100_q_ema_x, eps_05_b_00100_q_r_ema, label="Ɛ=0.5 β=0.00100")
plt.plot(eps_05_b_00200_q_ema_x, eps_05_b_00200_q_r_ema, label="Ɛ=0.5 β=0.00200")
plt.xlabel("episodes")
plt.legend()
plt.ylabel("R")

plt.title("Q - R EMA")
plt.plot(eps_09_b_00100_q_ema_x, eps_09_b_00100_q_r_ema, label="Ɛ=0.9 β=0.00100")
plt.plot(eps_09_b_00200_q_ema_x, eps_09_b_00200_q_r_ema, label="Ɛ=0.9 β=0.00200")
plt.plot(eps_09_b_00500_q_ema_x, eps_09_b_00500_q_r_ema, label="Ɛ=0.9 β=0.00500")
plt.legend()
plt.xlabel("episodes")
plt.ylabel("R")

new_figure()
plt.title("Q - N EMA")
plt.plot(eps_05_b_00005_q_ema_x, eps_05_b_00005_q_n_ema , label="Ɛ=0.5 β=0.00005")
plt.plot(eps_05_b_00050_q_ema_x, eps_05_b_00050_q_n_ema, label="Ɛ=0.5 β=0.00050")
plt.plot(eps_05_b_00100_q_ema_x, eps_05_b_00100_q_n_ema, label="Ɛ=0.5 β=0.00100")
plt.plot(eps_05_b_00200_q_ema_x, eps_05_b_00200_q_n_ema, label="Ɛ=0.5 β=0.00200")
plt.xlabel("episodes")
plt.legend()
plt.ylabel("N")

plt.title("Q - N EMA")
# plt.plot(eps_09_b_00100_q_ema_x, eps_09_b_00100_q_n_ema, label="Ɛ=0.9 β=0.00100")
# plt.plot(eps_09_b_00200_q_ema_x, eps_09_b_00200_q_n_ema, label="Ɛ=0.9 β=0.00200")
# plt.plot(eps_09_b_00500_q_ema_x, eps_09_b_00500_q_n_ema, label="Ɛ=0.9 β=0.00500")
plt.legend()
plt.xlabel("episodes")
plt.ylabel("N")
# Out:
# Text(0, 0.5, 'N')

# %%
new_figure()
plt.title("s - R EMA")
# plt.plot(eps_05_b_00005_s_ema_x, eps_05_b_00005_s_r_ema , label="Ɛ=0.5 β=0.00005")
# plt.plot(eps_05_b_00050_s_ema_x, eps_05_b_00050_s_r_ema, label="Ɛ=0.5 β=0.00050")
plt.plot(eps_05_b_00100_s_ema_x, eps_05_b_00100_s_r_ema, label="Ɛ=0.5 β=0.00100")
plt.plot(eps_05_b_00200_s_ema_x, eps_05_b_00200_s_r_ema, label="Ɛ=0.5 β=0.00200")
plt.xlabel("episodes")
plt.legend()
plt.ylabel("R")

# new_figure()
plt.title("s - R EMA")
plt.plot(eps_09_b_00100_s_ema_x, eps_09_b_00100_s_r_ema, label="Ɛ=0.9 β=0.00100")
plt.plot(eps_09_b_00200_s_ema_x, eps_09_b_00200_s_r_ema, label="Ɛ=0.9 β=0.00200")
# plt.plot(eps_09_b_00500_s_ema_x, eps_09_b_00500_s_r_ema, label="Ɛ=0.9 β=0.00500")
plt.legend()
plt.xlabel("episodes")
plt.ylabel("R")

new_figure()
plt.title("s - N EMA")
plt.plot(eps_05_b_00005_s_ema_x, eps_05_b_00005_s_n_ema , label="Ɛ=0.5 β=0.00005")
plt.plot(eps_05_b_00050_s_ema_x, eps_05_b_00050_s_n_ema, label="Ɛ=0.5 β=0.00050")
plt.plot(eps_05_b_00100_s_ema_x, eps_05_b_00100_s_n_ema, label="Ɛ=0.5 β=0.00100")
plt.plot(eps_05_b_00200_s_ema_x, eps_05_b_00200_s_n_ema, label="Ɛ=0.5 β=0.00200")
plt.xlabel("episodes")
plt.legend()
plt.ylabel("R")

# new_figure()
plt.title("s - N EMA")
# plt.plot(eps_09_b_00100_s_ema_x, eps_09_b_00100_s_n_ema, label="Ɛ=0.9 β=0.00100")
# plt.plot(eps_09_b_00200_s_ema_x, eps_09_b_00200_s_n_ema, label="Ɛ=0.9 β=0.00200")
# plt.plot(eps_09_b_00500_s_ema_x, eps_09_b_00500_s_n_ema, label="Ɛ=0.9 β=0.00500")
plt.legend()
plt.xlabel("episodes")
plt.ylabel("N")


new_figure()
plt.title("s - N EMA")
plt.plot(eps_05_gamma_05_s_ema_x, eps_05_gamma_05_s_n_ema , label="Ɛ=0.5 γ=0.05")
plt.plot(eps_05_gamma_08_s_ema_x, eps_05_gamma_08_s_n_ema, label="Ɛ=0.5 γ=0.08")
plt.plot(eps_05_gamma_99_s_ema_x, eps_05_gamma_99_s_n_ema, label="Ɛ=0.5 γ=0.99")
plt.xlabel("episodes")
plt.legend()
plt.ylabel("R")

# new_figure()
plt.title("s - N EMA")
plt.plot(eps_05_gamma_05_s_ema_x, eps_05_gamma_05_s_n_ema, label="Ɛ=0.5 γ=0.05")
plt.plot(eps_05_gamma_08_s_ema_x, eps_05_gamma_08_s_n_ema, label="Ɛ=0.5 γ=0.08")
plt.plot(eps_05_gamma_99_s_ema_x, eps_05_gamma_99_s_n_ema, label="Ɛ=0.5 γ=0.99")
plt.legend()
plt.xlabel("episodes")
plt.ylabel("N")
# Out:
# Text(0, 0.5, 'N')

# %%
new_figure()
plt.title("dq - R EMA")
# plt.plot(eps_05_b_00005_dq_ema_x, eps_05_b_00005_dq_r_ema , label="Ɛ=0.5 β=0.00005")
# plt.plot(eps_05_b_00050_dq_ema_x, eps_05_b_00050_dq_r_ema, label="Ɛ=0.5 β=0.00050")
plt.plot(eps_05_b_00100_dq_ema_x, eps_05_b_00100_dq_r_ema, label="Ɛ=0.5 β=0.00100")
plt.plot(eps_09_b_00100_dq_ema_x, eps_09_b_00100_dq_r_ema, label="Ɛ=0.9 β=0.00100")
plt.xlabel("episodes")
plt.legend()
plt.ylabel("R")

# new_figure()
plt.title("dq - R EMA")
plt.plot(eps_05_b_00200_dq_ema_x, eps_05_b_00200_dq_r_ema, label="Ɛ=0.5 β=0.00200")
plt.plot(eps_09_b_00200_dq_ema_x, eps_09_b_00200_dq_r_ema, label="Ɛ=0.9 β=0.00200")
# plt.plot(eps_09_b_00500_dq_ema_x, eps_09_b_00500_dq_r_ema, label="Ɛ=0.9 β=0.00500")
plt.legend()
plt.xlabel("episodes")
plt.ylabel("R")
# Out:
# Text(0, 0.5, 'R')
